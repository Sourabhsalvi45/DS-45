# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

from pandas import read_excel
from pandas import read_csv
import math
import seaborn as sns
from pylab import rcParams

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
# %matplotlib inline

# %% [markdown]
# #Reading The Patients Data

# %%
# load the dataset

dataframe = read_csv('/content/patients.csv')
dataframe
# Out:
#                                         Id   BIRTHDATE DEATHDATE          SSN  \
# 0     b9c610cd-28a6-4636-ccb6-c7a0d2a4cb85  2019-02-17       NaN  999-65-3251
# 1     c1f1fcaa-82fd-d5b7-3544-c8f9708b06a8  2005-07-04       NaN  999-49-3323
# 2     339144f8-50e1-633e-a013-f361391c4cff  1998-05-11       NaN  999-10-8743
# 3     d488232e-bf14-4bed-08c0-a82f34b6a197  2003-01-28       NaN  999-56-6057
# 4     217f95a3-4e10-bd5d-fb67-0cfb5e8ba075  1993-12-23       NaN  999-91-4320
# ...                                    ...         ...       ...          ...
# 1158  409330fa-7ffd-dbfb-4eba-2349d58a6324  1979-02-28       NaN  999-68-5445
# 1159  cb328021-a854-dc94-e7ae-426580477308  1964-05-31       NaN  999-10-6445
# 1160  41862157-5c14-f706-4a94-d2929be969e7  1967-07-12       NaN  999-63-2407
# 1161  d53c57a5-4480-2481-32ee-b2844a991c9d  1948-07-28       NaN  999-37-8036
# 1162  cb1b2c74-d1c5-997c-6f8b-20ca9f332eef  1958-11-07       NaN  999-17-1411
#
#         DRIVERS    PASSPORT PREFIX       FIRST            LAST SUFFIX  ...  \
# 0           NaN         NaN    NaN    Damon455      Langosh790    NaN  ...
# 1     S99941126         NaN    NaN       Thi53       Wunsch504    NaN  ...
# 2     S99996708  X75063318X    Mr.      Chi716  Greenfelder433    NaN  ...
# 3     S99929424         NaN    Ms.  Phillis443       Walter473    NaN  ...
# 4     S99991143  X44132498X    Mr.  Jerrold404       Herzog843    NaN  ...
# ...         ...         ...    ...         ...             ...    ...  ...
# 1158  S99991649  X72884711X    Mr.      Coy949      Schaden604    NaN  ...
# 1159  S99986790  X86596484X   Mrs.   Sherry479      Barrows492    NaN  ...
# 1160  S99976335  X68999803X    Mr.    Vance413   Jakubowski832    NaN  ...
# 1161  S99939062  X79037907X    Mr.     Cody889        Hilll811    NaN  ...
# 1162  S99963285   X2822177X    Mr.  Haywood675    Schroeder447    NaN  ...
#
#                             BIRTHPLACE                           ADDRESS  \
# 0     Middleborough  Massachusetts  US            620 Lynch Tunnel Apt 0
# 1           Danvers  Massachusetts  US       972 Tillman Branch Suite 48
# 2        Athens  Athens Prefecture  GR  1060 Bernhard Crossroad Suite 15
# 3            Boston  Massachusetts  US               677 Ritchie Terrace
# 4            Boston  Massachusetts  US                276 Bernier Branch
# ...                                ...                               ...
# 1158      Fitchburg  Massachusetts  US    434 Hickle Throughway Suite 15
# 1159         Boston  Massachusetts  US                 976 Ortiz Orchard
# 1160       Brockton  Massachusetts  US                534 Strosin Corner
# 1161       Stoneham  Massachusetts  US                568 Ryan Stravenue
# 1162        Peabody  Massachusetts  US       707 Heathcote Wall Suite 15
#
#              CITY          STATE             COUNTY     ZIP        LAT  \
# 0     Springfield  Massachusetts     Hampden County  1104.0  42.080389
# 1      Bellingham  Massachusetts     Norfolk County     NaN  42.035213
# 2          Boston  Massachusetts     Suffolk County  2131.0  42.292557
# 3         Hingham  Massachusetts    Plymouth County  2043.0  42.200491
# 4          Revere  Massachusetts     Suffolk County     NaN  42.381875
# ...           ...            ...                ...     ...        ...
# 1158      Amherst  Massachusetts   Hampshire County     NaN  42.380084
# 1159    Stoughton  Massachusetts     Norfolk County     NaN  42.081223
# 1160      Gardner  Massachusetts   Worcester County  1440.0  42.604215
# 1161      Mashpee  Massachusetts  Barnstable County     NaN  41.577704
# 1162   Marblehead  Massachusetts       Essex County     NaN  42.466700
#
#             LON HEALTHCARE_EXPENSES HEALTHCARE_COVERAGE
# 0    -72.480431        9.039165e+03           7964.1255
# 1    -71.482519        4.027234e+05          14064.1350
# 2    -71.061160        5.719359e+05            787.5375
# 3    -70.916076        5.825578e+05         104782.2070
# 4    -70.999286        4.758269e+05          18067.0950
# ...         ...                 ...                 ...
# 1158 -72.527376        1.050937e+06            346.5075
# 1159 -71.126028        8.031471e+05         553335.4420
# 1160 -72.013243        1.028321e+06          28607.5050
# 1161 -70.507460        2.638801e+05         155042.0520
# 1162 -70.903323        1.548721e+06            217.1100
#
# [1163 rows x 25 columns]

# %%
dataframe=dataframe.rename(columns={"Id": "PATIENTID"})

# %%
dataframe.dtypes
# Out:
# PATIENTID               object
# BIRTHDATE               object
# DEATHDATE               object
# SSN                     object
# DRIVERS                 object
# PASSPORT                object
# PREFIX                  object
# FIRST                   object
# LAST                    object
# SUFFIX                  object
# MAIDEN                  object
# MARITAL                 object
# RACE                    object
# ETHNICITY               object
# GENDER                  object
# BIRTHPLACE              object
# ADDRESS                 object
# CITY                    object
# STATE                   object
# COUNTY                  object
# ZIP                    float64
# LAT                    float64
# LON                    float64
# HEALTHCARE_EXPENSES    float64
# HEALTHCARE_COVERAGE    float64
# dtype: object

# %%
# load the dataset

dataframe1 = read_csv('/content/conditions.csv')
dataframe1
# Out:
#             START        STOP                               PATIENT  \
# 0      2013-06-24  2013-07-02  c1f1fcaa-82fd-d5b7-3544-c8f9708b06a8
# 1      2016-02-27  2016-03-14  c1f1fcaa-82fd-d5b7-3544-c8f9708b06a8
# 2      2016-08-11  2016-08-22  c1f1fcaa-82fd-d5b7-3544-c8f9708b06a8
# 3      2016-11-27  2016-12-17  c1f1fcaa-82fd-d5b7-3544-c8f9708b06a8
# 4      2017-02-22  2017-06-02  c1f1fcaa-82fd-d5b7-3544-c8f9708b06a8
# ...           ...         ...                                   ...
# 38089  2020-01-10  2021-01-15  cb1b2c74-d1c5-997c-6f8b-20ca9f332eef
# 38090  2020-12-27  2021-01-03  cb1b2c74-d1c5-997c-6f8b-20ca9f332eef
# 38091  2021-01-15         NaN  cb1b2c74-d1c5-997c-6f8b-20ca9f332eef
# 38092  2021-01-15         NaN  cb1b2c74-d1c5-997c-6f8b-20ca9f332eef
# 38093  2021-01-15         NaN  cb1b2c74-d1c5-997c-6f8b-20ca9f332eef
#
#                                   ENCOUNTER       CODE  \
# 0      0b2794bd-ec2b-d34f-0610-2523b3b7fcf0   10509002
# 1      a6d818dd-0983-fd1c-eefa-3d2295532c45  283371005
# 2      36d2e781-4655-0a11-1f70-c69856e02019  444814009
# 3      c8eaaf41-958b-31ab-7de5-568cee8751f3  444814009
# 4      6474f606-5a1b-48c0-bbbf-ad6dcbc24d4e   16114001
# ...                                     ...        ...
# 38089  090096d3-9404-3cb5-d1eb-583bf4c39180  160903007
# 38090  db101ad8-66e2-9feb-e0cf-b2618f873c3a   38822007
# 38091  1516d2e6-4846-5f1e-fe27-c1ebb9a39f72  160904001
# 38092  1516d2e6-4846-5f1e-fe27-c1ebb9a39f72   73595000
# 38093  1516d2e6-4846-5f1e-fe27-c1ebb9a39f72  706893006
#
#                                       DESCRIPTION
# 0                     Acute bronchitis (disorder)
# 1                           Laceration of forearm
# 2                      Viral sinusitis (disorder)
# 3                      Viral sinusitis (disorder)
# 4                               Fracture of ankle
# ...                                           ...
# 38089              Full-time employment (finding)
# 38090                                    Cystitis
# 38091              Part-time employment (finding)
# 38092                            Stress (finding)
# 38093  Victim of intimate partner abuse (finding)
#
# [38094 rows x 6 columns]

# %%
dataframe1=dataframe1.rename(columns={"PATIENT": "PATIENTID"})

# %%
dataframe1.dtypes
# Out:
# START          object
# STOP           object
# PATIENTID      object
# ENCOUNTER      object
# CODE            int64
# DESCRIPTION    object
# dtype: object

# %% [markdown]
# #Clean The Data by Dropping Unwanted CLoumns / Rows

# %% [markdown]
# Data cleaning
# Drop irrelevant columns

# %%
dataframe = dataframe.drop(['DRIVERS', 'SUFFIX'], axis=1)

# %%
# Remove duplicate records
dataframe = dataframe.drop_duplicates()

# %% [markdown]
# #Merge datasets based on common columns (Integrate Records)

# %%
df = pd.merge(dataframe, dataframe1, on='PATIENTID', how='inner')

# %%
df
# Out:
#                                   PATIENTID   BIRTHDATE DEATHDATE  \
# 0      c1f1fcaa-82fd-d5b7-3544-c8f9708b06a8  2005-07-04       NaN
# 1      c1f1fcaa-82fd-d5b7-3544-c8f9708b06a8  2005-07-04       NaN
# 2      c1f1fcaa-82fd-d5b7-3544-c8f9708b06a8  2005-07-04       NaN
# 3      c1f1fcaa-82fd-d5b7-3544-c8f9708b06a8  2005-07-04       NaN
# 4      c1f1fcaa-82fd-d5b7-3544-c8f9708b06a8  2005-07-04       NaN
# ...                                     ...         ...       ...
# 38089  cb1b2c74-d1c5-997c-6f8b-20ca9f332eef  1958-11-07       NaN
# 38090  cb1b2c74-d1c5-997c-6f8b-20ca9f332eef  1958-11-07       NaN
# 38091  cb1b2c74-d1c5-997c-6f8b-20ca9f332eef  1958-11-07       NaN
# 38092  cb1b2c74-d1c5-997c-6f8b-20ca9f332eef  1958-11-07       NaN
# 38093  cb1b2c74-d1c5-997c-6f8b-20ca9f332eef  1958-11-07       NaN
#
#                SSN   PASSPORT PREFIX       FIRST          LAST MAIDEN MARITAL  \
# 0      999-49-3323        NaN    NaN       Thi53     Wunsch504    NaN     NaN
# 1      999-49-3323        NaN    NaN       Thi53     Wunsch504    NaN     NaN
# 2      999-49-3323        NaN    NaN       Thi53     Wunsch504    NaN     NaN
# 3      999-49-3323        NaN    NaN       Thi53     Wunsch504    NaN     NaN
# 4      999-49-3323        NaN    NaN       Thi53     Wunsch504    NaN     NaN
# ...            ...        ...    ...         ...           ...    ...     ...
# 38089  999-17-1411  X2822177X    Mr.  Haywood675  Schroeder447    NaN       M
# 38090  999-17-1411  X2822177X    Mr.  Haywood675  Schroeder447    NaN       M
# 38091  999-17-1411  X2822177X    Mr.  Haywood675  Schroeder447    NaN       M
# 38092  999-17-1411  X2822177X    Mr.  Haywood675  Schroeder447    NaN       M
# 38093  999-17-1411  X2822177X    Mr.  Haywood675  Schroeder447    NaN       M
#
#        ... ZIP        LAT        LON HEALTHCARE_EXPENSES HEALTHCARE_COVERAGE  \
# 0      ... NaN  42.035213 -71.482519          402723.415           14064.135
# 1      ... NaN  42.035213 -71.482519          402723.415           14064.135
# 2      ... NaN  42.035213 -71.482519          402723.415           14064.135
# 3      ... NaN  42.035213 -71.482519          402723.415           14064.135
# 4      ... NaN  42.035213 -71.482519          402723.415           14064.135
# ...    ...  ..        ...        ...                 ...                 ...
# 38089  ... NaN  42.466700 -70.903323         1548720.970             217.110
# 38090  ... NaN  42.466700 -70.903323         1548720.970             217.110
# 38091  ... NaN  42.466700 -70.903323         1548720.970             217.110
# 38092  ... NaN  42.466700 -70.903323         1548720.970             217.110
# 38093  ... NaN  42.466700 -70.903323         1548720.970             217.110
#
#             START        STOP                             ENCOUNTER  \
# 0      2013-06-24  2013-07-02  0b2794bd-ec2b-d34f-0610-2523b3b7fcf0
# 1      2016-02-27  2016-03-14  a6d818dd-0983-fd1c-eefa-3d2295532c45
# 2      2016-08-11  2016-08-22  36d2e781-4655-0a11-1f70-c69856e02019
# 3      2016-11-27  2016-12-17  c8eaaf41-958b-31ab-7de5-568cee8751f3
# 4      2017-02-22  2017-06-02  6474f606-5a1b-48c0-bbbf-ad6dcbc24d4e
# ...           ...         ...                                   ...
# 38089  2020-01-10  2021-01-15  090096d3-9404-3cb5-d1eb-583bf4c39180
# 38090  2020-12-27  2021-01-03  db101ad8-66e2-9feb-e0cf-b2618f873c3a
# 38091  2021-01-15         NaN  1516d2e6-4846-5f1e-fe27-c1ebb9a39f72
# 38092  2021-01-15         NaN  1516d2e6-4846-5f1e-fe27-c1ebb9a39f72
# 38093  2021-01-15         NaN  1516d2e6-4846-5f1e-fe27-c1ebb9a39f72
#
#             CODE                                 DESCRIPTION
# 0       10509002                 Acute bronchitis (disorder)
# 1      283371005                       Laceration of forearm
# 2      444814009                  Viral sinusitis (disorder)
# 3      444814009                  Viral sinusitis (disorder)
# 4       16114001                           Fracture of ankle
# ...          ...                                         ...
# 38089  160903007              Full-time employment (finding)
# 38090   38822007                                    Cystitis
# 38091  160904001              Part-time employment (finding)
# 38092   73595000                            Stress (finding)
# 38093  706893006  Victim of intimate partner abuse (finding)
#
# [38094 rows x 28 columns]

# %%
df.dtypes
# Out:
# PATIENTID               object
# BIRTHDATE               object
# DEATHDATE               object
# SSN                     object
# PASSPORT                object
# PREFIX                  object
# FIRST                   object
# LAST                    object
# MAIDEN                  object
# MARITAL                 object
# RACE                    object
# ETHNICITY               object
# GENDER                  object
# BIRTHPLACE              object
# ADDRESS                 object
# CITY                    object
# STATE                   object
# COUNTY                  object
# ZIP                    float64
# LAT                    float64
# LON                    float64
# HEALTHCARE_EXPENSES    float64
# HEALTHCARE_COVERAGE    float64
# START                   object
# STOP                    object
# ENCOUNTER               object
# CODE                     int64
# DESCRIPTION             object
# dtype: object

# %% [markdown]
# # Data transformation
# Apply transformations to columns

# %%
# Convert date columns to datetime format
df['START'] = pd.to_datetime(df['START'])
df['STOP'] = pd.to_datetime(df['STOP'])

# %%
df.dtypes
# Out:
# PATIENTID                      object
# BIRTHDATE                      object
# DEATHDATE                      object
# SSN                            object
# PASSPORT                       object
# PREFIX                         object
# FIRST                          object
# LAST                           object
# MAIDEN                         object
# MARITAL                        object
# RACE                           object
# ETHNICITY                      object
# GENDER                         object
# BIRTHPLACE                     object
# ADDRESS                        object
# CITY                           object
# STATE                          object
# COUNTY                         object
# ZIP                           float64
# LAT                           float64
# LON                           float64
# HEALTHCARE_EXPENSES           float64
# HEALTHCARE_COVERAGE           float64
# START                  datetime64[ns]
# STOP                   datetime64[ns]
# ENCOUNTER                      object
# CODE                            int64
# DESCRIPTION                    object
# dtype: object

# %% [markdown]
# #### Calculate length of HEALTHCARE_COVERAGE

# %%
df['HEALTHCARE_COVERAGE_LENGTH'] = (df['STOP'] - df['START']).dt.days

# %% [markdown]
# ### Apply data transformations to categorical variables

# %%
df['GENDER'] = df['GENDER'].map({'M': 'Male', 'F': 'Female'})

# %% [markdown]
# ## Save the cleaned, integrated, and transformed dataset

# %%
# Save the cleaned, integrated, and transformed dataset
df.to_csv('/content/cleaned_records.csv', index=False)

# %%
df.describe()
# Out:
#                 ZIP           LAT           LON  HEALTHCARE_EXPENSES  \
# count  20605.000000  38094.000000  38094.000000         3.809400e+04
# mean    1996.638534     42.245420    -71.354238         2.041481e+06
# min     1001.000000     41.299942    -73.445165         5.147439e+03
# 25%     1830.000000     42.089248    -71.535785         1.115480e+06
# 50%     2116.000000     42.295183    -71.145240         1.799452e+06
# 75%     2190.000000     42.462164    -71.011924         2.286987e+06
# max     2861.000000     42.888532    -69.978831         2.311655e+07
# std      452.698853      0.294193      0.641146         2.619780e+06
#
#        HEALTHCARE_COVERAGE                          START  \
# count         3.809400e+04                          38094
# mean          4.007928e+05  2001-12-21 16:24:00.226807296
# min           0.000000e+00            1919-06-06 00:00:00
# 25%           1.198805e+04            1991-09-22 12:00:00
# 50%           1.338132e+05            2009-06-20 12:00:00
# 75%           3.765214e+05            2016-07-12 00:00:00
# max           1.356228e+07            2021-11-15 00:00:00
# std           1.335352e+06                            NaN
#
#                                 STOP          CODE  HEALTHCARE_COVERAGE_LENGTH
# count                          29925  3.809400e+04                29925.000000
# mean   2004-05-01 20:59:04.060150272  4.927406e+13                  584.985664
# min              1922-08-31 00:00:00  1.734006e+06                    0.000000
# 25%              1995-03-08 00:00:00  8.475701e+07                   84.000000
# 50%              2012-04-09 00:00:00  1.609030e+08                  371.000000
# 75%              2017-08-13 00:00:00  2.242990e+08                  406.000000
# max              2021-11-18 00:00:00  1.093988e+16                20195.000000
# std                              NaN  7.292378e+14                 1111.793865
